# %% [markdown]
# # Линейная регрессия. Практическая работа

# %% [markdown]
# ## Цель практической работы
#
# Научиться строить модель линейной регрессии на реальных данных.

# %% [markdown]
# ## Что входит в практическую работу
#
#
# 1. Загрузить данные и ознакомиться с ними.
# 2. Изучить данные и провести анализ.
# 3. Разделить данные на обучающую и тестовую выборки.
# 4. Реализовать построение модели с помощью  библиотеки scikit-learn.
# 5. Получить качество модели с помощью MSE, MAE.

# %% [markdown]
# ## Что оценивается
#
# * Выполнены все этапы работы.
# * Сделан вывод по результатам.
# * Модель не переобучена.
# * Получена модель хорошего качества.

# %% [markdown]
# ## Как отправить работу на проверку
#
# Скачайте файл с заданиями в материалах, откройте его через Jupyter Notebook и выполните задачи. Сохраните изменения при помощи опции Save and Checkpoint из вкладки меню File или кнопки Save and Checkpoint на панели инструментов. Отправьте через форму ниже итоговый файл Jupyter Notebook (в формате .ipynb) или ссылку на него.

# %% [markdown]
# ## Что нужно сделать
#
# Пусть у нас имеется некоторый набор данных `sales.csv` о продажах квартир:
#
# - **SalePrice** (цена продажи, *зависимая переменная*).
# - **GrLivArea** (наземная жилая зона).
# - **OverallQuality** (общее качество).
# - **GarageArea** (территория гаража).
# - **SaleCondition** (условия сделки).
#
# Реализуйте построение модели линейной регрессии на этих данных. Проверьте качество модели на обучающей и тестовой выборках с помощью MAE, MSE. Определите, что вы не переобучились.

# %% [markdown]
# ### 1. Импорт библиотек

# %%
import numpy as np

# обработка данных
import pandas as pd

# визуализация
import seaborn as sns
import matplotlib.pyplot as plt

# стандартизация данных
from sklearn.preprocessing import MinMaxScaler

# обучение модели
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# метрики
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ### 2. Загрузка данных

# %%
# Ваш код здесь
sales_df = pd.read_csv('sales.csv')
sales_df
# Out:
#       SalePrice  GrLivArea  GarageArea  OverallQual Street SaleCondition
# 0        208500       1710         548            7   Pave        Normal
# 1        181500       1262         460            6   Pave        Normal
# 2        223500       1786         608            7   Pave        Normal
# 3        140000       1717         642            7   Pave       Abnorml
# 4        250000       2198         836            8   Pave        Normal
# ...         ...        ...         ...          ...    ...           ...
# 1455     175000       1647         460            6   Pave        Normal
# 1456     210000       2073         500            6   Pave        Normal
# 1457     266500       2340         252            7   Pave        Normal
# 1458     142125       1078         240            5   Pave        Normal
# 1459     147500       1256         276            5   Pave        Normal
#
# [1460 rows x 6 columns]

# %% [markdown]
# ### 3. Первичный анализ
#
# 1. Проведите анализ данных, посмотрите на индивидуальные графики зависимости целевой функции и отдельной переменной. Нередко, если признаков в выборке не так много, удобно построить [sns.pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html).
# 2. Закодируйте категориальные признаки (например, с помощью [pd.get_dummies](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html)).
# 3. Подумайте, можно ли здесь создать дополнительные переменные из имеющихся.
# 4. Сделайте предварительные выводы.

# %%
# Ваш код здесь
sns.pairplot(sales_df, y_vars="SalePrice")
plt.show()

# %%
sns.pairplot(sales_df, hue="Street",  y_vars="SalePrice")
print("with visualization parameter: 'Street'")
plt.show()
# Out:
# with visualization parameter: 'Street'

# %%
sns.pairplot(sales_df, hue="SaleCondition",  y_vars="SalePrice")
print("with visualization parameter: 'SaleCondition'")
plt.show()
# Out:
# with visualization parameter: 'SaleCondition'

# %%
def otliers_cleaning(df, col):
    def calculate_outliers(data):
        q25 = data.quantile(0.25)
        q75 = data.quantile(0.75)
        iqr = q75 - q25
        
        boundaries = (q25 - 1.5 * iqr, q75 + 1.5 * iqr)
        return boundaries
    
        
    boundaries = calculate_outliers(df[col])
    #Подсчитать количество значений, которые больше верхней границы или меньше нижней границы
    is_outlier = (df[col] < boundaries[0]) | (df[col] > boundaries[1])
    
    is_outlier.sum()
    
    print(f"{is_outlier.sum() / len(df)}% записей в колонке {col} удаляем") # процент выбросов относительно общего количества записей в датасете

    # df = df[(df[col] < boundaries[1]) & (df[col] > boundaries[0])]
    df.loc[df[col] > boundaries[1], col] = int(boundaries[1])  
    df.loc[df[col] < boundaries[0], col] = int(boundaries[0])
    #которые были больше верхней границы или меньше нижней границы boundaries, заменили на граничные значения
    return df

columns_list = ['SalePrice', 'GrLivArea', 'GarageArea', 'OverallQual']

for colname in columns_list:
    otliers_cleaning(sales_df, colname)

sns.pairplot(sales_df, hue="SaleCondition",  y_vars="SalePrice")
print("with visualization parameter: 'SaleCondition'")
plt.show()
# Out:
# 0.04178082191780822% записей в колонке SalePrice удаляем
# 0.021232876712328767% записей в колонке GrLivArea удаляем
# 0.014383561643835616% записей в колонке GarageArea удаляем
# 0.0013698630136986301% записей в колонке OverallQual удаляем
# with visualization parameter: 'SaleCondition'

# %%
# Новые фитчи
sales_df['devis_Area_OverallQual'] = (sales_df['GrLivArea'] + sales_df['GarageArea']) / sales_df['OverallQual']

sales_df['log_GarageArea'] = sales_df['GarageArea'].apply(lambda x: np.log1p(x))

# # sale_ohe_df['power3_GrLivArea'] = sale_ohe_df['GrLivArea'].apply(lambda x: np.power(x, 3))

sales_df['cos_OverallQual'] = sales_df['OverallQual'].apply(lambda x: np.cos(x))
sales_df['sin_OverallQual'] = sales_df['OverallQual'].apply(lambda x: np.sin(x))
sales_df['tan_OverallQual'] = sales_df['OverallQual'].apply(lambda x: np.tan(x))



sales_df['sin_GarageArea'] = sales_df['GarageArea'].apply(lambda x: np.sin(x))
sales_df['cos_GarageArea'] = sales_df['GarageArea'].apply(lambda x: np.cos(x))
sales_df['tan_GarageArea'] = sales_df['GarageArea'].apply(lambda x: np.tan(x))

sales_df['cos_GrLivArea'] = sales_df['GrLivArea'].apply(lambda x: np.cos(x))
sales_df['sin_GrLivArea'] = sales_df['GrLivArea'].apply(lambda x: np.sin(x))
sales_df['tan_GrLivArea'] = sales_df['GrLivArea'].apply(lambda x: np.tan(x))

# # sale_ohe_df['GrLivArea_plus_GarageArea'] = sale_ohe_df['GrLivArea']+sale_ohe_df['GarageArea']
# # sale_ohe_df['cos_GrLivArea_plus_GarageArea'] = sale_ohe_df['GrLivArea_plus_GarageArea'].apply(lambda x: np.cos(x))
# # sale_ohe_df['sin_GrLivArea_plus_GarageArea'] = sale_ohe_df['GrLivArea_plus_GarageArea'].apply(lambda x: np.sin(x))

# # sale_ohe_df['division_GrLivAreaplus_OverallQual'] = sale_ohe_df['GrLivArea_plus_GarageArea']/sale_ohe_df['OverallQual']
# # sale_ohe_df['sin_division_GrLivAreaplus_OverallQual'] = sale_ohe_df['division_GrLivAreaplus_OverallQual'].apply(lambda x: np.cos(x))
# # sale_ohe_df['tan_division_GrLivAreaplus_OverallQual'] = sale_ohe_df['division_GrLivAreaplus_OverallQual'].apply(lambda x: np.tan(x))
plus_fitches = ['devis_Area_OverallQual'
                , 'cos_GrLivArea'
                , 'sin_GrLivArea'
                # , 'tan_GrLivArea'               
                # , 'log_GarageArea'
                , 'cos_OverallQual'
                , 'sin_OverallQual']
                # , 'tan_OverallQual'
                # , 'sin_GarageArea'
                # , 'cos_GarageArea']
                # , 'tan_GarageArea']

# %%
from sklearn.preprocessing import PolynomialFeatures

columns_to_polym = ['GrLivArea', 'GarageArea', 'OverallQual'] #+ plus_fitches
# 1. Разделите датафрейм на фичи и целевую переменную
X = sales_df[columns_to_polym]  # фичи

# 2. Примените PolynomialFeatures к фичам
poly = PolynomialFeatures(degree=5)
X_poly = poly.fit_transform(X)

# 3. Создайте новый датафрейм с полиномиальными фичами
X_poly_df = pd.DataFrame(X_poly, columns=poly.get_feature_names_out(X.columns))
X_poly_df.drop(columns=['1']+columns_to_polym, inplace=True)
# 4. Добавьте обратно целевую переменную
sales_df = pd.concat([X_poly_df.reset_index(drop=True), sales_df.reset_index(drop=True)], axis=1)
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 69 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   GrLivArea^2                           1460 non-null   float64
#  1   GrLivArea GarageArea                  1460 non-null   float64
#  2   GrLivArea OverallQual                 1460 non-null   float64
#  3   GarageArea^2                          1460 non-null   float64
#  4   GarageArea OverallQual                1460 non-null   float64
#  5   OverallQual^2                         1460 non-null   float64
#  6   GrLivArea^3                           1460 non-null   float64
#  7   GrLivArea^2 GarageArea                1460 non-null   float64
#  8   GrLivArea^2 OverallQual               1460 non-null   float64
#  9   GrLivArea GarageArea^2                1460 non-null   float64
#  10  GrLivArea GarageArea OverallQual      1460 non-null   float64
#  11  GrLivArea OverallQual^2               1460 non-null   float64
#  12  GarageArea^3                          1460 non-null   float64
#  13  GarageArea^2 OverallQual              1460 non-null   float64
#  14  GarageArea OverallQual^2              1460 non-null   float64
#  15  OverallQual^3                         1460 non-null   float64
#  16  GrLivArea^4                           1460 non-null   float64
#  17  GrLivArea^3 GarageArea                1460 non-null   float64
#  18  GrLivArea^3 OverallQual               1460 non-null   float64
#  19  GrLivArea^2 GarageArea^2              1460 non-null   float64
#  20  GrLivArea^2 GarageArea OverallQual    1460 non-null   float64
#  21  GrLivArea^2 OverallQual^2             1460 non-null   float64
#  22  GrLivArea GarageArea^3                1460 non-null   float64
#  23  GrLivArea GarageArea^2 OverallQual    1460 non-null   float64
#  24  GrLivArea GarageArea OverallQual^2    1460 non-null   float64
#  25  GrLivArea OverallQual^3               1460 non-null   float64
#  26  GarageArea^4                          1460 non-null   float64
#  27  GarageArea^3 OverallQual              1460 non-null   float64
#  28  GarageArea^2 OverallQual^2            1460 non-null   float64
#  29  GarageArea OverallQual^3              1460 non-null   float64
#  30  OverallQual^4                         1460 non-null   float64
#  31  GrLivArea^5                           1460 non-null   float64
#  32  GrLivArea^4 GarageArea                1460 non-null   float64
#  33  GrLivArea^4 OverallQual               1460 non-null   float64
#  34  GrLivArea^3 GarageArea^2              1460 non-null   float64
#  35  GrLivArea^3 GarageArea OverallQual    1460 non-null   float64
#  36  GrLivArea^3 OverallQual^2             1460 non-null   float64
#  37  GrLivArea^2 GarageArea^3              1460 non-null   float64
#  38  GrLivArea^2 GarageArea^2 OverallQual  1460 non-null   float64
#  39  GrLivArea^2 GarageArea OverallQual^2  1460 non-null   float64
#  40  GrLivArea^2 OverallQual^3             1460 non-null   float64
#  41  GrLivArea GarageArea^4                1460 non-null   float64
#  42  GrLivArea GarageArea^3 OverallQual    1460 non-null   float64
#  43  GrLivArea GarageArea^2 OverallQual^2  1460 non-null   float64
#  44  GrLivArea GarageArea OverallQual^3    1460 non-null   float64
#  45  GrLivArea OverallQual^4               1460 non-null   float64
#  46  GarageArea^5                          1460 non-null   float64
#  47  GarageArea^4 OverallQual              1460 non-null   float64
#  48  GarageArea^3 OverallQual^2            1460 non-null   float64
#  49  GarageArea^2 OverallQual^3            1460 non-null   float64
#  50  GarageArea OverallQual^4              1460 non-null   float64
#  51  OverallQual^5                         1460 non-null   float64
#  52  SalePrice                             1460 non-null   int64
#  53  GrLivArea                             1460 non-null   int64
#  54  GarageArea                            1460 non-null   int64
#  55  OverallQual                           1460 non-null   int64
#  56  Street                                1460 non-null   object
#  57  SaleCondition                         1460 non-null   object
#  58  devis_Area_OverallQual                1460 non-null   float64
#  59  log_GarageArea                        1460 non-null   float64
#  60  cos_OverallQual                       1460 non-null   float64
#  61  sin_OverallQual                       1460 non-null   float64
#  62  tan_OverallQual                       1460 non-null   float64
#  63  sin_GarageArea                        1460 non-null   float64
#  64  cos_GarageArea                        1460 non-null   float64
#  65  tan_GarageArea                        1460 non-null   float64
#  66  cos_GrLivArea                         1460 non-null   float64
#  67  sin_GrLivArea                         1460 non-null   float64
#  68  tan_GrLivArea                         1460 non-null   float64
# dtypes: float64(63), int64(4), object(2)
# memory usage: 787.2+ KB

# %%
print(len(poly.get_feature_names_out(X.columns)[1:]))
poly.get_feature_names_out(X.columns)
# Out:
# 55
# array(['1', 'GrLivArea', 'GarageArea', 'OverallQual', 'GrLivArea^2',
#        'GrLivArea GarageArea', 'GrLivArea OverallQual', 'GarageArea^2',
#        'GarageArea OverallQual', 'OverallQual^2', 'GrLivArea^3',
#        'GrLivArea^2 GarageArea', 'GrLivArea^2 OverallQual',
#        'GrLivArea GarageArea^2', 'GrLivArea GarageArea OverallQual',
#        'GrLivArea OverallQual^2', 'GarageArea^3',
#        'GarageArea^2 OverallQual', 'GarageArea OverallQual^2',
#        'OverallQual^3', 'GrLivArea^4', 'GrLivArea^3 GarageArea',
#        'GrLivArea^3 OverallQual', 'GrLivArea^2 GarageArea^2',
#        'GrLivArea^2 GarageArea OverallQual', 'GrLivArea^2 OverallQual^2',
#        'GrLivArea GarageArea^3', 'GrLivArea GarageArea^2 OverallQual',
#        'GrLivArea GarageArea OverallQual^2', 'GrLivArea OverallQual^3',
#        'GarageArea^4', 'GarageArea^3 OverallQual',
#        'GarageArea^2 OverallQual^2', 'GarageArea OverallQual^3',
#        'OverallQual^4', 'GrLivArea^5', 'GrLivArea^4 GarageArea',
#        'GrLivArea^4 OverallQual', 'GrLivArea^3 GarageArea^2',
#        'GrLivArea^3 GarageArea OverallQual', 'GrLivArea^3 OverallQual^2',
#        'GrLivArea^2 GarageArea^3', 'GrLivArea^2 GarageArea^2 OverallQual',
#        'GrLivArea^2 GarageArea OverallQual^2',
#        'GrLivArea^2 OverallQual^3', 'GrLivArea GarageArea^4',
#        'GrLivArea GarageArea^3 OverallQual',
#        'GrLivArea GarageArea^2 OverallQual^2',
#        'GrLivArea GarageArea OverallQual^3', 'GrLivArea OverallQual^4',
#        'GarageArea^5', 'GarageArea^4 OverallQual',
#        'GarageArea^3 OverallQual^2', 'GarageArea^2 OverallQual^3',
#        'GarageArea OverallQual^4', 'OverallQual^5'], dtype=object)

# %% [markdown]
# Задача: Закодируйте категориальные признаки (например, с помощью pd.get_dummies)

# %%
new_cat_df = pd.get_dummies(sales_df[['SaleCondition', 'Street']], dtype=int)
new_cat_df
# Out:
#       SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# 0                         0                      0                     0
# 1                         0                      0                     0
# 2                         0                      0                     0
# 3                         1                      0                     0
# 4                         0                      0                     0
# ...                     ...                    ...                   ...
# 1455                      0                      0                     0
# 1456                      0                      0                     0
# 1457                      0                      0                     0
# 1458                      0                      0                     0
# 1459                      0                      0                     0
#
#       SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial  \
# 0                        0                     1                      0
# 1                        0                     1                      0
# 2                        0                     1                      0
# 3                        0                     0                      0
# 4                        0                     1                      0
# ...                    ...                   ...                    ...
# 1455                     0                     1                      0
# 1456                     0                     1                      0
# 1457                     0                     1                      0
# 1458                     0                     1                      0
# 1459                     0                     1                      0
#
#       Street_Grvl  Street_Pave
# 0               0            1
# 1               0            1
# 2               0            1
# 3               0            1
# 4               0            1
# ...           ...          ...
# 1455            0            1
# 1456            0            1
# 1457            0            1
# 1458            0            1
# 1459            0            1
#
# [1460 rows x 8 columns]

# %%
sale_ohe_df = pd.concat([sales_df.drop(columns=['SaleCondition', 'Street']), new_cat_df], axis = 1)
sale_ohe_df
# Out:
#       GrLivArea^2  GrLivArea GarageArea  GrLivArea OverallQual  GarageArea^2  \
# 0       2924100.0              937080.0                11970.0      300304.0
# 1       1592644.0              580520.0                 7572.0      211600.0
# 2       3189796.0             1085888.0                12502.0      369664.0
# 3       2948089.0             1102314.0                12019.0      412164.0
# 4       4831204.0             1837528.0                17584.0      698896.0
# ...           ...                   ...                    ...           ...
# 1455    2712609.0              757620.0                 9882.0      211600.0
# 1456    4297329.0             1036500.0                12438.0      250000.0
# 1457    5475600.0              589680.0                16380.0       63504.0
# 1458    1162084.0              258720.0                 5390.0       57600.0
# 1459    1577536.0              346656.0                 6280.0       76176.0
#
#       GarageArea OverallQual  OverallQual^2   GrLivArea^3  \
# 0                     3836.0           49.0  5.000211e+09
# 1                     2760.0           36.0  2.009917e+09
# 2                     4256.0           49.0  5.696976e+09
# 3                     4494.0           49.0  5.061869e+09
# 4                     6688.0           64.0  1.061899e+10
# ...                      ...            ...           ...
# 1455                  2760.0           36.0  4.467667e+09
# 1456                  3000.0           36.0  8.908363e+09
# 1457                  1764.0           49.0  1.281290e+10
# 1458                  1200.0           25.0  1.252727e+09
# 1459                  1380.0           25.0  1.981385e+09
#
#       GrLivArea^2 GarageArea  GrLivArea^2 OverallQual  GrLivArea GarageArea^2  \
# 0               1.602407e+09               20468700.0            5.135198e+08
# 1               7.326162e+08                9555864.0            2.670392e+08
# 2               1.939396e+09               22328572.0            6.602199e+08
# 3               1.892673e+09               20636623.0            7.076856e+08
# 4               4.038887e+09               38649632.0            1.536173e+09
# ...                      ...                      ...                     ...
# 1455            1.247800e+09               16275654.0            3.485052e+08
# 1456            2.148664e+09               25783974.0            5.182500e+08
# 1457            1.379851e+09               38329200.0            1.485994e+08
# 1458            2.789002e+08                5810420.0            6.209280e+07
# 1459            4.353999e+08                7887680.0            9.567706e+07
#
#       ...  sin_GrLivArea  tan_GrLivArea  SaleCondition_Abnorml  \
# 0     ...       0.826913       1.470515                      0
# 1     ...      -0.795751      -1.313936                      0
# 2     ...       0.999990    -218.509209                      0
# 3     ...       0.992855      -8.320259                      1
# 4     ...      -0.897848      -2.039148                      0
# ...   ...            ...            ...                    ...
# 1455  ...       0.721142       1.040929                      0
# 1456  ...      -0.436002      -0.484476                      0
# 1457  ...       0.467559      -0.528935                      0
# 1458  ...      -0.420249       0.463131                      0
# 1459  ...      -0.594836      -0.739986                      0
#
#       SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 1455                      0                     0                     0
# 1456                      0                     0                     0
# 1457                      0                     0                     0
# 1458                      0                     0                     0
# 1459                      0                     0                     0
#
#       SaleCondition_Normal  SaleCondition_Partial  Street_Grvl  Street_Pave
# 0                        1                      0            0            1
# 1                        1                      0            0            1
# 2                        1                      0            0            1
# 3                        0                      0            0            1
# 4                        1                      0            0            1
# ...                    ...                    ...          ...          ...
# 1455                     1                      0            0            1
# 1456                     1                      0            0            1
# 1457                     1                      0            0            1
# 1458                     1                      0            0            1
# 1459                     1                      0            0            1
#
# [1460 rows x 75 columns]

# %% [markdown]
# Подумайте, можно ли здесь создать дополнительные переменные из имеющихся.

# %%
sale_ohe_df['Street_Grvl'].value_counts()
# Out:
# Street_Grvl
# 0    1454
# 1       6
# Name: count, dtype: int64

# %%
print('раз параметр Street может принимать только 2 параметра, предпологаю что можно избавиться от Street_Grvl и оставить Street_Pave')
sale_ohe_df.drop(columns=['Street_Grvl'], inplace=True)
# Out:
# раз параметр Street может принимать только 2 параметра, предпологаю что можно избавиться от Street_Grvl и оставить Street_Pave

# %%
print(sale_ohe_df.columns)
sale_ohe_df.info()
# Out:
# Index(['GrLivArea^2', 'GrLivArea GarageArea', 'GrLivArea OverallQual',
#        'GarageArea^2', 'GarageArea OverallQual', 'OverallQual^2',
#        'GrLivArea^3', 'GrLivArea^2 GarageArea', 'GrLivArea^2 OverallQual',
#        'GrLivArea GarageArea^2', 'GrLivArea GarageArea OverallQual',
#        'GrLivArea OverallQual^2', 'GarageArea^3', 'GarageArea^2 OverallQual',
#        'GarageArea OverallQual^2', 'OverallQual^3', 'GrLivArea^4',
#        'GrLivArea^3 GarageArea', 'GrLivArea^3 OverallQual',
#        'GrLivArea^2 GarageArea^2', 'GrLivArea^2 GarageArea OverallQual',
#        'GrLivArea^2 OverallQual^2', 'GrLivArea GarageArea^3',
#        'GrLivArea GarageArea^2 OverallQual',
#        'GrLivArea GarageArea OverallQual^2', 'GrLivArea OverallQual^3',
#        'GarageArea^4', 'GarageArea^3 OverallQual',
#        'GarageArea^2 OverallQual^2', 'GarageArea OverallQual^3',
#        'OverallQual^4', 'GrLivArea^5', 'GrLivArea^4 GarageArea',
#        'GrLivArea^4 OverallQual', 'GrLivArea^3 GarageArea^2',
#        'GrLivArea^3 GarageArea OverallQual', 'GrLivArea^3 OverallQual^2',
#        'GrLivArea^2 GarageArea^3', 'GrLivArea^2 GarageArea^2 OverallQual',
#        'GrLivArea^2 GarageArea OverallQual^2', 'GrLivArea^2 OverallQual^3',
#        'GrLivArea GarageArea^4', 'GrLivArea GarageArea^3 OverallQual',
#        'GrLivArea GarageArea^2 OverallQual^2',
#        'GrLivArea GarageArea OverallQual^3', 'GrLivArea OverallQual^4',
#        'GarageArea^5', 'GarageArea^4 OverallQual',
#        'GarageArea^3 OverallQual^2', 'GarageArea^2 OverallQual^3',
#        'GarageArea OverallQual^4', 'OverallQual^5', 'SalePrice', 'GrLivArea',
#        'GarageArea', 'OverallQual', 'devis_Area_OverallQual', 'log_GarageArea',
#        'cos_OverallQual', 'sin_OverallQual', 'tan_OverallQual',
#        'sin_GarageArea', 'cos_GarageArea', 'tan_GarageArea', 'cos_GrLivArea',
#        'sin_GrLivArea', 'tan_GrLivArea', 'SaleCondition_Abnorml',
#        'SaleCondition_AdjLand', 'SaleCondition_Alloca', 'SaleCondition_Family',
#        'SaleCondition_Normal', 'SaleCondition_Partial', 'Street_Pave'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   GrLivArea^2                           1460 non-null   float64
#  1   GrLivArea GarageArea                  1460 non-null   float64
#  2   GrLivArea OverallQual                 1460 non-null   float64
#  3   GarageArea^2                          1460 non-null   float64
#  4   GarageArea OverallQual                1460 non-null   float64
#  5   OverallQual^2                         1460 non-null   float64
#  6   GrLivArea^3                           1460 non-null   float64
#  7   GrLivArea^2 GarageArea                1460 non-null   float64
#  8   GrLivArea^2 OverallQual               1460 non-null   float64
#  9   GrLivArea GarageArea^2                1460 non-null   float64
#  10  GrLivArea GarageArea OverallQual      1460 non-null   float64
#  11  GrLivArea OverallQual^2               1460 non-null   float64
#  12  GarageArea^3                          1460 non-null   float64
#  13  GarageArea^2 OverallQual              1460 non-null   float64
#  14  GarageArea OverallQual^2              1460 non-null   float64
#  15  OverallQual^3                         1460 non-null   float64
#  16  GrLivArea^4                           1460 non-null   float64
#  17  GrLivArea^3 GarageArea                1460 non-null   float64
#  18  GrLivArea^3 OverallQual               1460 non-null   float64
#  19  GrLivArea^2 GarageArea^2              1460 non-null   float64
#  20  GrLivArea^2 GarageArea OverallQual    1460 non-null   float64
#  21  GrLivArea^2 OverallQual^2             1460 non-null   float64
#  22  GrLivArea GarageArea^3                1460 non-null   float64
#  23  GrLivArea GarageArea^2 OverallQual    1460 non-null   float64
#  24  GrLivArea GarageArea OverallQual^2    1460 non-null   float64
#  25  GrLivArea OverallQual^3               1460 non-null   float64
#  26  GarageArea^4                          1460 non-null   float64
#  27  GarageArea^3 OverallQual              1460 non-null   float64
#  28  GarageArea^2 OverallQual^2            1460 non-null   float64
#  29  GarageArea OverallQual^3              1460 non-null   float64
#  30  OverallQual^4                         1460 non-null   float64
#  31  GrLivArea^5                           1460 non-null   float64
#  32  GrLivArea^4 GarageArea                1460 non-null   float64
#  33  GrLivArea^4 OverallQual               1460 non-null   float64
#  34  GrLivArea^3 GarageArea^2              1460 non-null   float64
#  35  GrLivArea^3 GarageArea OverallQual    1460 non-null   float64
#  36  GrLivArea^3 OverallQual^2             1460 non-null   float64
#  37  GrLivArea^2 GarageArea^3              1460 non-null   float64
#  38  GrLivArea^2 GarageArea^2 OverallQual  1460 non-null   float64
#  39  GrLivArea^2 GarageArea OverallQual^2  1460 non-null   float64
#  40  GrLivArea^2 OverallQual^3             1460 non-null   float64
#  41  GrLivArea GarageArea^4                1460 non-null   float64
#  42  GrLivArea GarageArea^3 OverallQual    1460 non-null   float64
#  43  GrLivArea GarageArea^2 OverallQual^2  1460 non-null   float64
#  44  GrLivArea GarageArea OverallQual^3    1460 non-null   float64
#  45  GrLivArea OverallQual^4               1460 non-null   float64
#  46  GarageArea^5                          1460 non-null   float64
#  47  GarageArea^4 OverallQual              1460 non-null   float64
#  48  GarageArea^3 OverallQual^2            1460 non-null   float64
#  49  GarageArea^2 OverallQual^3            1460 non-null   float64
#  50  GarageArea OverallQual^4              1460 non-null   float64
#  51  OverallQual^5                         1460 non-null   float64
#  52  SalePrice                             1460 non-null   int64
#  53  GrLivArea                             1460 non-null   int64
#  54  GarageArea                            1460 non-null   int64
#  55  OverallQual                           1460 non-null   int64
#  56  devis_Area_OverallQual                1460 non-null   float64
#  57  log_GarageArea                        1460 non-null   float64
#  58  cos_OverallQual                       1460 non-null   float64
#  59  sin_OverallQual                       1460 non-null   float64
#  60  tan_OverallQual                       1460 non-null   float64
#  61  sin_GarageArea                        1460 non-null   float64
#  62  cos_GarageArea                        1460 non-null   float64
#  63  tan_GarageArea                        1460 non-null   float64
#  64  cos_GrLivArea                         1460 non-null   float64
#  65  sin_GrLivArea                         1460 non-null   float64
#  66  tan_GrLivArea                         1460 non-null   float64
#  67  SaleCondition_Abnorml                 1460 non-null   int64
#  68  SaleCondition_AdjLand                 1460 non-null   int64
#  69  SaleCondition_Alloca                  1460 non-null   int64
#  70  SaleCondition_Family                  1460 non-null   int64
#  71  SaleCondition_Normal                  1460 non-null   int64
#  72  SaleCondition_Partial                 1460 non-null   int64
#  73  Street_Pave                           1460 non-null   int64
# dtypes: float64(63), int64(11)
# memory usage: 844.2 KB

# %%
print('Стоит стандартизировать переменные GrLivArea GarageArea OverallQual')
print('MinMaxScaler думаю подходит лучше, для дальнейшей интерпритации влияния на целевую переменную')
print(poly.get_feature_names_out(X.columns))
numeric_columns = poly.get_feature_names_out(X.columns)[1:]
print("\n",numeric_columns)
#['GrLivArea^2', 'GrLivArea GarageArea', 'GrLivArea OverallQual',
       # 'GarageArea^2', 'GarageArea OverallQual', 'OverallQual^2',
       # 'GrLivArea', 'GarageArea', 'OverallQual']


mm_scaler = MinMaxScaler()
mm_scaler.fit(sale_ohe_df[numeric_columns])
minmax_matrix = mm_scaler.transform(sale_ohe_df[numeric_columns])

new_col_names = []
for col in numeric_columns:
    new_col_names.append('scl_'+str(col))


sale_ohe_df[new_col_names] = minmax_matrix
# Out:
# Стоит стандартизировать переменные GrLivArea GarageArea OverallQual
# MinMaxScaler думаю подходит лучше, для дальнейшей интерпритации влияния на целевую переменную
# ['1' 'GrLivArea' 'GarageArea' 'OverallQual' 'GrLivArea^2'
#  'GrLivArea GarageArea' 'GrLivArea OverallQual' 'GarageArea^2'
#  'GarageArea OverallQual' 'OverallQual^2' 'GrLivArea^3'
#  'GrLivArea^2 GarageArea' 'GrLivArea^2 OverallQual'
#  'GrLivArea GarageArea^2' 'GrLivArea GarageArea OverallQual'
#  'GrLivArea OverallQual^2' 'GarageArea^3' 'GarageArea^2 OverallQual'
#  'GarageArea OverallQual^2' 'OverallQual^3' 'GrLivArea^4'
#  'GrLivArea^3 GarageArea' 'GrLivArea^3 OverallQual'
#  'GrLivArea^2 GarageArea^2' 'GrLivArea^2 GarageArea OverallQual'
#  'GrLivArea^2 OverallQual^2' 'GrLivArea GarageArea^3'
#  'GrLivArea GarageArea^2 OverallQual' 'GrLivArea GarageArea OverallQual^2'
#  'GrLivArea OverallQual^3' 'GarageArea^4' 'GarageArea^3 OverallQual'
#  'GarageArea^2 OverallQual^2' 'GarageArea OverallQual^3' 'OverallQual^4'
#  'GrLivArea^5' 'GrLivArea^4 GarageArea' 'GrLivArea^4 OverallQual'
#  'GrLivArea^3 GarageArea^2' 'GrLivArea^3 GarageArea OverallQual'
#  'GrLivArea^3 OverallQual^2' 'GrLivArea^2 GarageArea^3'
#  'GrLivArea^2 GarageArea^2 OverallQual'
#  'GrLivArea^2 GarageArea OverallQual^2' 'GrLivArea^2 OverallQual^3'
#  'GrLivArea GarageArea^4' 'GrLivArea GarageArea^3 OverallQual'
#  'GrLivArea GarageArea^2 OverallQual^2'
#  'GrLivArea GarageArea OverallQual^3' 'GrLivArea OverallQual^4'
#  'GarageArea^5' 'GarageArea^4 OverallQual' 'GarageArea^3 OverallQual^2'
#  'GarageArea^2 OverallQual^3' 'GarageArea OverallQual^4' 'OverallQual^5']
#
#  ['GrLivArea' 'GarageArea' 'OverallQual' 'GrLivArea^2'
#  'GrLivArea GarageArea' 'GrLivArea OverallQual' 'GarageArea^2'
#  'GarageArea OverallQual' 'OverallQual^2' 'GrLivArea^3'
#  'GrLivArea^2 GarageArea' 'GrLivArea^2 OverallQual'
#  'GrLivArea GarageArea^2' 'GrLivArea GarageArea OverallQual'
#  'GrLivArea OverallQual^2' 'GarageArea^3' 'GarageArea^2 OverallQual'
#  'GarageArea OverallQual^2' 'OverallQual^3' 'GrLivArea^4'
#  'GrLivArea^3 GarageArea' 'GrLivArea^3 OverallQual'
#  'GrLivArea^2 GarageArea^2' 'GrLivArea^2 GarageArea OverallQual'
#  'GrLivArea^2 OverallQual^2' 'GrLivArea GarageArea^3'
#  'GrLivArea GarageArea^2 OverallQual' 'GrLivArea GarageArea OverallQual^2'
#  'GrLivArea OverallQual^3' 'GarageArea^4' 'GarageArea^3 OverallQual'
#  'GarageArea^2 OverallQual^2' 'GarageArea OverallQual^3' 'OverallQual^4'
#  'GrLivArea^5' 'GrLivArea^4 GarageArea' 'GrLivArea^4 OverallQual'
#  'GrLivArea^3 GarageArea^2' 'GrLivArea^3 GarageArea OverallQual'
#  'GrLivArea^3 OverallQual^2' 'GrLivArea^2 GarageArea^3'
#  'GrLivArea^2 GarageArea^2 OverallQual'
#  'GrLivArea^2 GarageArea OverallQual^2' 'GrLivArea^2 OverallQual^3'
#  'GrLivArea GarageArea^4' 'GrLivArea GarageArea^3 OverallQual'
#  'GrLivArea GarageArea^2 OverallQual^2'
#  'GrLivArea GarageArea OverallQual^3' 'GrLivArea OverallQual^4'
#  'GarageArea^5' 'GarageArea^4 OverallQual' 'GarageArea^3 OverallQual^2'
#  'GarageArea^2 OverallQual^3' 'GarageArea OverallQual^4' 'OverallQual^5']

# %%
sale_ohe_df.drop(columns=numeric_columns, inplace=True)
print('После стандартизации, Удалили исходные колонки')
# Out:
# После стандартизации, Удалили исходные колонки

# %% [markdown]
# ### 4. Разделение на обучающую и тестовую выборки

# %%
targets_df = sale_ohe_df['SalePrice']
fitches_df = sale_ohe_df.drop(columns=['SalePrice'])

print("Разделили на фитчи и целевую перменную")
# Out:
# Разделили на фитчи и целевую перменную

# %%
# Ваш код здесь
fitches_train, fitches_test, target_train, target_test = train_test_split(fitches_df, targets_df, test_size=0.3, random_state=42)
print("fitches_train: ", fitches_train.shape)
print("fitches_test: ", fitches_test.shape)
print("target_train: ", target_train.shape)
print("target_test: ", target_test.shape)
# Out:
# fitches_train:  (1022, 73)
# fitches_test:  (438, 73)
# target_train:  (1022,)
# target_test:  (438,)

# %% [markdown]
# ### 5. Обучение модели линейной регрессии
#
# Дополнительно можно взглянуть на коэффициенты и смещение обученной модели.

# %%
# Ваш код здесь
# from sklearn.linear_model import Lasso
liner_reg = LinearRegression(n_jobs=-1)#, positive=True) #Lasso(alpha=1.0)
liner_reg.fit(fitches_train, target_train)
print("модель обучена")
# Out:
# модель обучена

# %% [markdown]
# ### 6. Получение предсказаний для обучающей и тестовой выборок

# %%
# Ваш код здесь
prediction_train = liner_reg.predict(fitches_train)
prediction_test = liner_reg.predict(fitches_test)
print("предикты получены")
# Out:
# предикты получены

# %% [markdown]
# Визуализация предиктов и целевой переменной

# %%
# График для тренировочных данных
# print(type(prediction_test))
# prediction_test = np.clip(prediction_test, np.min(prediction_train), np.max(prediction_train))

plt.scatter(target_train, prediction_train, color='blue', label='Train data', alpha=0.5)
# График для тестовых данных
plt.scatter(target_test, prediction_test, color='red', label='Test data', alpha=0.5)

# Линия идеальных предсказаний
plt.plot([min(target_train.min(), target_test.min()), max(target_train.max(), target_test.max())], 
         [min(target_train.min(), target_test.min()), max(target_train.max(), target_test.max())], 
         'k--', lw=2)

plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title('Actual vs Predicted values')
plt.legend()
plt.show()

# %% [markdown]
# ### 7. Проверка предсказаний
#
# 1. Проверьте качество модели на обучающей и тестовой выборках с помощью MAE, MSE.
# 2. Постройте диаграмму рассеяния целевой и предсказанной переменных.

# %%
# Ваш код здесь

mse_train = mean_squared_error(target_train, prediction_train)
mse_test = mean_squared_error(target_test, prediction_test)

mae_train = mean_absolute_error(target_train, prediction_train)
mae_test = mean_absolute_error(target_test, prediction_test)

print("MSE:")
print(f'MSE (train): {mse_train}')
print(f'MSE (test): {mse_test}')

print("\nMAE:")
print(f'MAE (train): {mae_train}')
print(f'MAE (test): {mae_test}')
# Out:
# MSE:
# MSE (train): 703278551.6551566
# MSE (test): 888606259.6067709
#
# MAE:
# MAE (train): 19854.1141455244
# MAE (test): 21471.712952054808

# %% [markdown]
# ### выводы

# %%
# Получение признаков и их коэффициентов
features = fitches_train.columns
coefficients = liner_reg.coef_

# Создание DataFrame для удобного вывода
feature_importance = pd.DataFrame({
    'Feature': features,
    'Coefficient': coefficients
})
pd.set_option('display.float_format', lambda x: '%.5f' % x)
feature_importance['Coefficient'].describe()
# Out:
# count           73.00000
# mean         20443.04909
# std      119682605.01648
# min     -675878999.67888
# 25%       -4341760.51431
# 50%          -1064.16041
# 75%        3805271.57310
# max      626566063.95153
# Name: Coefficient, dtype: float64

# %%
from sklearn.feature_selection import SelectKBest, f_regression, f_classif

# Выборка 10 лучших признаков
selector = SelectKBest(score_func=f_regression, k=33)
X_train_selected = selector.fit_transform(fitches_train, target_train)
X_test_selected = selector.transform(fitches_test)



# Обучение модели на выбранных признаках
liner_reg.fit(X_train_selected, target_train)

# Предсказание на тренировочных и тестовых данных
y_train_pred = liner_reg.predict(X_train_selected)
y_test_pred = liner_reg.predict(X_test_selected)

# Вычисление метрик
mse_train = mean_squared_error(target_train, y_train_pred)
mse_test = mean_squared_error(target_test, y_test_pred)
mae_train = mean_absolute_error(target_train, y_train_pred)
mae_test = mean_absolute_error(target_test, y_test_pred)

print("MSE на тренировочных данных:", mse_train)
print("MSE на тестовых данных:", mse_test)
print("MAE на тренировочных данных:", mae_train)
print("MAE на тестовых данных:", mae_test)
# Out:
# MSE на тренировочных данных: 774911084.4465346
# MSE на тестовых данных: 699802739.4939721
# MAE на тренировочных данных: 20608.39917416599
# MAE на тестовых данных: 19621.067352533144

# %%
plt.scatter(target_train, y_train_pred, color='blue', label='Train data', alpha=0.5)
# График для тестовых данных
plt.scatter(target_test, y_test_pred, color='red', label='Test data', alpha=0.5)

# Линия идеальных предсказаний
plt.plot([min(target_train.min(), target_test.min()), max(target_train.max(), target_test.max())], 
         [min(target_train.min(), target_test.min()), max(target_train.max(), target_test.max())], 
         'k--', lw=2)

plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title('Actual vs Predicted values')
plt.legend()
plt.show()
